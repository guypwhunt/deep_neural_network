# %% [markdown]
# # Image Classification Model Based on a Convolutional Neural Network with TensorFlow
#
# The following notebook contains a Convolutional Neural Network (CNN) used to identify if an image contains a circle, square or triangle.

# %%
# Import Tensorflow Libraries
import tensorflow
from  tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

# Import Other Libraries
import os
# %matplotlib inline
import numpy as np
# %matplotlib inline
from random import randint
import ipywidgets as widgets
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
from IPython.display import display, clear_output

# %% [markdown]
# ## 1. Prepare the data
#
# The feature values are divided by 255 to normalize them as floating-point values between 0 and 1. Next, the data is split with 70% of the data for training the model, and 30% of the data for validating the model. As the data is loaded, the data generator will assign "hot-encoded" numeric labels to indicate which class each image belongs to based on the subfolders in which the data is stored. There are three subfolders - *circle*, *square*, and *triangle*, so the labels will consist of three *0* or *1* values indicating which of these classes is associated with the image - for example the label [0 1 0] indicates that the image belongs to the second class (*square*).
#
# The folder containing the data loaded into the model can be seen on this link:
# https://mybinder.org/v2/gh/guypwhunt/deep_neural_network/HEAD?filepath=%2Fdata%2Fshapes

# %%
data_folder = 'data/shapes'
img_size = (128, 128)
batch_size = 30

datagen = ImageDataGenerator(rescale=1./255, # normalize pixel values
                             validation_split=0.3) # hold back 30% of the images for validation

print("The training dataset contains:")
train_generator = datagen.flow_from_directory(
    data_folder,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training') # set as training data

print("\nThe validation dataset contains:")
validation_generator = datagen.flow_from_directory(
    data_folder,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation') # set as validation data

classnames = list(train_generator.class_indices.keys())
print("\nThe classes contained within the dataset are: ", classnames)
# Out:
# The training dataset contains:
# Found 840 images belonging to 3 classes.
#
# The validation dataset contains:
# Found 360 images belonging to 3 classes.
#
# The classes contained within the dataset are:  ['circle', 'square', 'triangle']

# %% [markdown]
# ## 2. Define the CNN
#
# The model is defined by defining the layers for our CNN and compiling them for multi-class classification.

# %%
# Define the model as a sequence of layers
model = Sequential()

# The input layer accepts an image and applies a convolution that uses 32 6x6 filters and a rectified linear unit activation function
model.add(Conv2D(32, (6, 6), input_shape=train_generator.image_shape, activation='relu'))

# Next we;ll add a max pooling layer with a 2x2 patch
model.add(MaxPooling2D(pool_size=(2,2)))

# We can add as many layers as we think necessary - here we'll add another convolution, max pooling, and dropout layer
model.add(Conv2D(32, (6, 6), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# And another set
model.add(Conv2D(32, (6, 6), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# A dropout layer randomly drops some nodes to reduce inter-dependencies (which can cause over-fitting)
model.add(Dropout(0.2))

# Now we'll flatten the feature maps and generate an output layer with a predicted probability for each class
model.add(Flatten())
model.add(Dense(train_generator.num_classes, activation='sigmoid'))

# With the layers defined, we can now compile the model for categorical (multi-class) classification
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 123, 123, 32)      3488
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 61, 61, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 32)        36896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 23, 23, 32)        36896
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 11, 11, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11, 11, 32)        0
# ...

# %% [markdown]
# ## 3. Train the model
#
# The model can now be trained using our image data. The model will be trained using 50 iterations (*epochs*) in 30-image batches, holding back 30% of the data for validation. After each epoch, the loss function measures the error (*loss*) in the model and adjusts the weights (which were randomly generated for the first iteration) to try to improve accuracy.
#
# With the layers of the CNN defined, we're ready to train the model using our image data. In the example below, we use 5 iterations (*epochs*) to train the model in 30-image batches, holding back 30% of the data for validation. After each epoch, the loss function measures the error (*loss*) in the model and adjusts the weights (which were randomly generated for the first iteration) to try to improve accuracy.
#
# It should be noted that at this point a previously saved model is loaded to reduce the loading time of the notebook as training the model takes a considerable amount of time on mybinder. However, the code to train the model can be found here: https://mybinder.org/v2/gh/guypwhunt/deep_neural_network/HEAD?filepath=convolutional_neural_networks_tensorflow.ipynb

# %%
# Train the model over 5 epochs using 30-image batches and using the validation holdout dataset for validation
num_epochs = 50
#history = model.fit(
#    train_generator,
#    steps_per_epoch = train_generator.samples // batch_size,
#    validation_data = validation_generator, 
#    validation_steps = validation_generator.samples // batch_size,
#    epochs = num_epochs)

# Save the trained model
#modelFileName = 'models/shape_classifier.h5'
#model.save(modelFileName)
#del model  # deletes the existing model variable

# Loading a pre-saved model
modelFileName = 'models/shape_classifier.h5'
model = models.load_model(modelFileName)

# Print epoch history 
print("""Epoch 1/50
28/28 [==============================] - 25s 871ms/step - loss: 0.9701 - accuracy: 0.5233 - val_loss: 0.3470 - val_accuracy: 0.8222
Epoch 2/50
28/28 [==============================] - 23s 833ms/step - loss: 0.2494 - accuracy: 0.9028 - val_loss: 0.0405 - val_accuracy: 0.9917
Epoch 3/50
28/28 [==============================] - 24s 857ms/step - loss: 0.0265 - accuracy: 0.9932 - val_loss: 0.0061 - val_accuracy: 1.0000
Epoch 4/50
28/28 [==============================] - 24s 832ms/step - loss: 0.0054 - accuracy: 0.9995 - val_loss: 0.0090 - val_accuracy: 0.9972
Epoch 5/50
28/28 [==============================] - 23s 821ms/step - loss: 0.0112 - accuracy: 0.9981 - val_loss: 0.0038 - val_accuracy: 1.0000
Epoch 6/50
28/28 [==============================] - 23s 833ms/step - loss: 0.0030 - accuracy: 0.9998 - val_loss: 0.0093 - val_accuracy: 0.9972
Epoch 7/50
28/28 [==============================] - 23s 825ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
Epoch 8/50
28/28 [==============================] - 24s 862ms/step - loss: 7.1439e-04 - accuracy: 1.0000 - val_loss: 6.9592e-04 - val_accuracy: 1.0000
Epoch 9/50
28/28 [==============================] - 24s 866ms/step - loss: 4.1761e-04 - accuracy: 1.0000 - val_loss: 3.7362e-04 - val_accuracy: 1.0000
Epoch 10/50
28/28 [==============================] - 23s 807ms/step - loss: 6.6538e-04 - accuracy: 1.0000 - val_loss: 3.3480e-04 - val_accuracy: 1.0000
Epoch 11/50
28/28 [==============================] - 24s 845ms/step - loss: 1.3243e-04 - accuracy: 1.0000 - val_loss: 3.0109e-04 - val_accuracy: 1.0000
Epoch 12/50
28/28 [==============================] - 24s 841ms/step - loss: 1.4682e-04 - accuracy: 1.0000 - val_loss: 3.3038e-04 - val_accuracy: 1.0000
Epoch 13/50
28/28 [==============================] - 25s 877ms/step - loss: 0.0069 - accuracy: 0.9974 - val_loss: 0.0031 - val_accuracy: 0.9972
Epoch 14/50
# 28/28 [==============================] - 24s 849ms/step - loss: 0.3046 - accuracy: 0.8392 - val_loss: 0.0916 - val_accuracy: 0.9722
# Epoch 3/50
# 28/28 [==============================] - 23s 804ms/step - loss: 0.0705 - accuracy: 0.9831 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 4/50
# 28/28 [==============================] - 23s 821ms/step - loss: 0.0153 - accuracy: 0.9994 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 5/50
# 28/28 [==============================] - 23s 834ms/step - loss: 0.0045 - accuracy: 0.9991 - val_loss: 0.0041 - val_accuracy: 0.9972
# Epoch 6/50
# 28/28 [==============================] - 24s 854ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 7/50
# ...

# %% [markdown]
# ## 4. View the loss history
#
# The average training and validation loss history for each epoch is plotted in a graph to verify that loss reduced as the model was trained, and to detect *overfitting* (which is indicated by a continued drop in training loss after validation loss has levelled out or started to increase).

# %%
epoch_nums = range(1,num_epochs+1)
# Uncomment the two lines below if you are re-training the model
#training_loss = history.history["loss"]
#validation_loss = history.history["val_loss"]

training_loss = [0.7173976898193359, 0.22538574039936066, 0.0473223514854908, 0.011174014769494534, 0.007790735922753811, 0.0044981446117162704, 0.010228085331618786, 0.008913638070225716, 0.0057371146976947784, 0.0010091321310028434, 0.0007717502885498106, 0.00027132549439556897, 0.0004098614735994488, 0.00022333768720272928, 0.00010239570838166401, 0.00027202480123378336, 0.00020378701447043568, 6.698339711874723e-05, 0.0003070575185120106, 0.0011174831306561828, 0.00041370850522071123, 9.783518908079714e-05, 0.00010184384882450104, 0.0006760168471373618, 0.00013117339403834194, 7.308318163268268e-05, 6.62112288409844e-05, 2.767955811577849e-05, 6.97271607350558e-05, 2.5456905859755352e-05, 4.4352575059747323e-05, 2.7721882361220196e-05, 4.116345371585339e-05, 2.2297452233033255e-05, 5.120999412611127e-05, 1.585577592777554e-05, 1.8032385924016126e-05, 2.2963691662880592e-05, 3.765818473766558e-05, 4.2390496673760936e-05, 3.708988879225217e-05, 2.489545295247808e-05, 1.764902481227182e-05, 1.8411830751574598e-05, 7.124123385437997e-06, 1.0745475265139248e-05, 1.6820960809127428e-05, 2.7637634048005566e-05, 1.5555406207568012e-05, 3.867475606966764e-05]
validation_loss = [0.369596391916275, 0.09161686152219772, 0.011512267403304577, 0.0027343365363776684, 0.004081143531948328, 0.001584786456078291, 0.0020897062495350838, 0.002521894872188568, 0.0014745102962478995, 0.0007080911891534925, 0.00030976839479990304, 0.0005268048262223601, 0.00017751744599081576, 0.00015074678231030703, 0.00012769967725034803, 0.00026590487686917186, 0.00015059691213537008, 0.00015545936184935272, 0.00021230048150755465, 0.0005812397575937212, 0.0002775555185507983, 0.00024198240134865046, 0.00016747467452660203, 0.0008149174391292036, 0.000111997956992127, 0.00012344514834694564, 0.00012020079884678125, 7.121956150513142e-05, 0.00011285609798505902, 0.00014840585936326534, 0.0001492219598731026, 0.00010894753359025344, 6.493604450952262e-05, 6.714960181852803e-05, 5.287181556923315e-05, 5.216875797486864e-05, 6.0627480706898496e-05, 5.564805542235263e-05, 7.95959567767568e-05, 7.001634367043152e-05, 3.5246452171122655e-05, 3.8543988921446726e-05, 5.215928831603378e-05, 7.865591032896191e-05, 8.881877147359774e-05, 8.341730426764116e-05, 0.0001057619447237812, 7.006846863077953e-05, 8.234144479501992e-05, 5.034439527662471e-05]

plt.plot(epoch_nums, training_loss)
plt.plot(epoch_nums, validation_loss)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# ## 5. Evaluate model performance
#
# A confusion matrix is plotted to see how well the model is predicting each class. You can see the model predicted some squares as triangles! This could be remediated by tweaking the training.

# %%
# Tensorflow doesn't have a built-in confusion matrix metric, so we'll use SciKit-Learn

# Get the image and label arrays for the first batch of validation data
x_test = validation_generator[0][0]
y_test = validation_generator[0][1]

# Use the model to predict the class
class_probabilities = model.predict(x_test)

# The model returns a probability value for each class
# The one with the highest probability is the predicted class
predictions = np.argmax(class_probabilities, axis=1)

# The actual labels are hot encoded (e.g. [0 1 0], so get the one with the value 1
true_labels = np.argmax(y_test, axis=1)

# Plot the confusion matrix
cm = confusion_matrix(true_labels, predictions)
plt.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
plt.colorbar()
tick_marks = np.arange(len(classnames))
plt.xticks(tick_marks, classnames, rotation=85)
plt.yticks(tick_marks, classnames)
plt.xlabel("Actual Shape")
plt.ylabel("Predicted Shape")
plt.show()

# %% [markdown]
# ## 6. Use the trained model
#
# The model can now be used to predict classes for the randomly generated image below. Refresh the web page to automatically generate a new image.

# %%
# Function to create a random image (of a square, circle, or triangle)
def create_image (size, shape):
    from random import randint
    import numpy as np
    from PIL import Image, ImageDraw
    
    xy1 = randint(10,40)
    xy2 = randint(60,100)
    col = (randint(0,200), randint(0,200), randint(0,200))

    img = Image.new("RGB", size, (255, 255, 255))
    draw = ImageDraw.Draw(img)
    
    if shape == 'circle':
        draw.ellipse([(xy1,xy1), (xy2,xy2)], fill=col)
    elif shape == 'triangle':
        draw.polygon([(xy1,xy1), (xy2,xy2), (xy2,xy1)], fill=col)
    else: # square
        draw.rectangle([(xy1,xy1), (xy2,xy2)], fill=col)
    del draw
    
    return np.array(img)

# Create a random test image
classnames = os.listdir(os.path.join('data', 'shapes'))
classnames.sort()
img = create_image ((128,128), classnames[randint(0, len(classnames)-1)])
plt.axis('off')
plt.imshow(img)

# The model expects a batch of images as input, so we'll create an array of 1 image
imgfeatures = img.reshape(1, img.shape[0], img.shape[1], img.shape[2])

# We need to format the input to match the training data
# The generator loaded the values as floating point numbers
# and normalized the pixel values, so...
imgfeatures = imgfeatures.astype('float32')
imgfeatures /= 255

# User interface
out = widgets.Output(layout={'border': '0.5px solid black'})

def predict_Shape(button): 
    # Create a new model class and load weights
    class_probabilities = model.predict(imgfeatures)
    # Find the class predictions with the highest predicted probability
    class_idx = np.argmax(class_probabilities, axis=1)
    global out
    with out:
        print (classnames[int(class_idx[0])])

        
predict_button=widgets.Button(
description='Predict Shape',
disabled=False,
button_style='primary', 
tooltip="Click to randomly create a shape and see if the CNN correctly predicted it",
icon='refresh')

button_form = widgets.VBox([predict_button, out])

display(button_form)

predict_button.on_click(predict_Shape)
